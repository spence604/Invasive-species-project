# %%
# import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import data from csv
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Current_Invasive_Plants_(Feature_Layer).csv')

# %%
df.describe()
# Out:
#            OBJECTID     TOTAL_AREA  INFESTED_AREA  INFESTED_PERCENT
# count  8.514060e+05  851406.000000  851406.000000     851406.000000
# mean   1.725331e+06       9.182018       5.740961         80.092965
# std    3.088785e+05     343.631772      87.658727         36.051270
# min    1.240939e+06       0.000000       0.000000          0.000000
# 25%    1.469482e+06       0.029200       0.015500         90.000000
# 50%    1.698648e+06       0.114100       0.099700        100.000000
# 75%    1.927614e+06       1.080400       0.656200        100.000000
# max    2.409319e+06  273643.944200   25044.539500        100.000000

# %%
df.head()
# Out:
#    OBJECTID               SITE_ID_FS ACCEPTED_PLANT_CODE  \
# 0   1240939  TNF-TBRD_2083_013_CEFO2               CEFO2
# 1   1240940       0419062008PDR40416               CIAR4
# 2   1240941       0419062008PDR40191                ISTI
# 3   1240942       0419062008PDR40207               CIAR4
# 4   1240943       0419062008PDR40436                CYOF
#
#   ACCEPTED_SCIENTIFIC_NAME        ACCEPTED_COMMON_NAME  \
# 0       Cerastium fontanum  common mouse-ear chickweed
# 1          Cirsium arvense              Canada thistle
# 2         Isatis tinctoria                 Dyer's woad
# 3          Cirsium arvense              Canada thistle
# 4   Cynoglossum officinale                 gypsyflower
#
#            DATE_COLLECTED  TOTAL_AREA  INFESTED_AREA  INFESTED_PERCENT  \
# 0  2005/09/07 00:00:00+00      0.0007         0.0007               100
# 1  2008/07/08 00:00:00+00      0.0681         0.0511                75
# ...

# %%
df.columns
# Out:
# Index(['OBJECTID', 'SITE_ID_FS', 'ACCEPTED_PLANT_CODE',
#        'ACCEPTED_SCIENTIFIC_NAME', 'ACCEPTED_COMMON_NAME', 'DATE_COLLECTED',
#        'TOTAL_AREA', 'INFESTED_AREA', 'INFESTED_PERCENT', 'FS_UNIT_NAME',
#        'CRC_VALUE'],
#       dtype='object')

# %%
df = df[['OBJECTID','ACCEPTED_COMMON_NAME', 'DATE_COLLECTED',
       'TOTAL_AREA', 'INFESTED_AREA', 'INFESTED_PERCENT',
       'CRC_VALUE']]

# %%
df.columns
# Out:
# Index(['OBJECTID', 'ACCEPTED_COMMON_NAME', 'DATE_COLLECTED', 'TOTAL_AREA',
#        'INFESTED_AREA', 'INFESTED_PERCENT', 'CRC_VALUE'],
#       dtype='object')

# %%
df.head()
# Out:
#    OBJECTID        ACCEPTED_COMMON_NAME          DATE_COLLECTED  TOTAL_AREA  \
# 0   1240939  common mouse-ear chickweed  2005/09/07 00:00:00+00      0.0007
# 1   1240940              Canada thistle  2008/07/08 00:00:00+00      0.0681
# 2   1240941                 Dyer's woad  2008/06/23 00:00:00+00      0.4465
# 3   1240942              Canada thistle  2008/06/24 00:00:00+00      0.3981
# 4   1240943                 gypsyflower  2008/07/09 00:00:00+00      0.0013
#
#    INFESTED_AREA  INFESTED_PERCENT         CRC_VALUE
# 0         0.0007               100  F864BA4A97F02DC2
# 1         0.0511                75  B26E9AB692FFD55B
# 2         0.2233                50  1C3C9199A5349559
# 3         0.2986                75  57980AA78DBFF2A8
# 4         0.0001                10  0FCAD722FC18D83E

# %%
df.to_csv('Cleaned Invasive Species.csv')

# %%
correl  = df.corr()

# %%
fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(correl, xticklabels = correl.columns, yticklabels = correl.columns, cmap='RdBu')
# Out:
# <AxesSubplot:>
